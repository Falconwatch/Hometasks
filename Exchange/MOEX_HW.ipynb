# %% [markdown]
# <a href="https://colab.research.google.com/github/Falconwatch/Hometasks/blob/main/Exchange/MOEX_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Описание
# В этом задании вам предстоит поработать с данными Московской Биржи и продемонсттрировать свои навыки обработки больших объмов данных
#
# ## Данные
# Данные представляют собой ZIP-файлы, содержащие сжатые CSV-файлы данных типа B с MOEX, т. е. данные по всем транзакциям и изменениям лучших бидов и предложений. Более подробная информация о различных типах данных MOEX доступна [здесь](https://www.moex.com/ru/orders?orderlogs)
#
# Данные для выполнения заданий размещены [здесь](https://disk.yandex.ru/d/WZTzpkCmHZyBjA)

# %% [markdown]
# # Задание 1 - Чистка данных
# Обработайте данные биржи:
# - Исключите плохие наблюдения, например с нулевой ценой или объёмом
# - Исключите наблюдения вне диапазона времени торгов (9:50-18:50)
# - Удалите дубликаты, если они есть
# - Обработайте пропуски, если они есть
# - Обработайте другие проблемы в данных, если они есть
#
# В виде одной таблицы саммаризуйте результат вашей работы: сколько наблюдений было исключено по каждому из пунктов выше

# %%
# Ваш код

# %% [markdown]
# # Задание 2 - Описательные статистики по торгам
# Выделите 15 ценных бумаг, являющихся голубыми фишками (по состоянию на 2 октября 2023 года - список определить [здесь](https://www.moex.com/ru/index/MOEXBC/constituents)) и рассчитайте по ним описательные статистики:
# - Средний дневной объем в рублях,
# - Дневную реализованную волатильность (квадратный корень из суммы всех квадратов логарифмических разностей цен в течение дня),
# - количество транзакций,
# - средний/медианный размер транзакций в рублях,
# - любую другую информацию, которая может оказаться вам полезной.

# %%
# ваш код здесь

# %% [markdown]
# # Задание 3 Вопросы по данным
# Ответьте на вопросы:
# - Какие акции были наиболее/наименее волатильными в течение исследуемого периода?
# - Какие акции имели наибольший/наименьший объем акций? рублевый объем?
# - Какие акции имели наибольшее/наименьший объем сделок?
# - Какие акции имели наибольшее/наименьший объем изменений котировок?
# - В какой день недели акции имели наибольший/наименьший объем в выборке?
# - Какие акции имели наибольший/наименьший спред спроса и предложения в рублях? процентный спред спроса и предложения?

# %%
# Ваш код здесь

# %% [markdown]
#  # Задание 4 - связь количества сделок и количества изменнеий цены
# Исследуйте, какова связь между количеством сделок и количеством изменений котировок? Например, постройте график логарифма количества сделок против логарифма количества изменений котировок, рассчитанных для каждой акции и каждого торгового дня.

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 5 - Внутридневные паттерны
# Объем торгов часто демонстрирует определенные внутридневные закономерности. Изучите внутридневные закономерности объма торгов, рассчитав средний объем в рублях в каждом 30-минутном периоде между 9:50 и 18:50.
#
# Акции сильно различаются по объему. Чтобы объединить данные по 15 акциям в один график, вы можете построить, например, типичную долю дневного объема, выполненного в течение каждого тридцатиминутного интервала (а затем усреднить по всем акциям). Как бы вы предложили обрабатывать первый и последний интервалы, учитывая, что они короче остальных интервалов?

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 6 - Проверка теории инвариантности
# В выполнении данного задания вам поможет [работа](https://pages.nes.ru/aobizhaeva/ABKO-intradayinv.pdf)
#
# ***Курсивом*** выделены дополнительные вопросы, ответ на которые не обязательны, но приветствуются
#
# Проверьте, соответствуют ли спреды спроса и предложения для набора акций голубых фишек прогнозам инвариантности.
#
# a) Постройте график ln(Spread/P) против ln(1/L). Проверьте, похож ли наклон на 1, как предсказывает инвариантность. ***Наблюдаете ли вы какие-либо интересные отклонения от прогнозов? Как их объяснить?***
#
# b) Раскрасьте наблюдения для разных акций разными цветами (всего 15 цветов). ***Видите ли вы какие-либо интересные закономерности?***
#
# c) Постройте график ln(Spread) против ln(P/L). Раскрасьте наблюдения для разных акций разными цветами (всего 15 цветов). ***Видите ли вы какие-либо интересные закономерности? Как их объяснить?***

# %%
# Ваш код здесь

# %% [markdown]
# # Задание 7 - Торговая стратегия
# Постройте следующую стратегию для 15 голубых фишек.
# В начале каждого часа для каждой акции проверьте дисбаланс по лучшему биду и лучшему предложению, а затем торгуйте в направлении дисбаланса. Если количество акций больше по лучшему аску (биду) по сравнению с лучшим бидом (аск), то продайте (купите) одну единицу акций. Повторите эту проверку для каждой из 15 акций и постройте соответствующий портфель. Держите открытую позицию в течение одного часа, затем закройте ее, повторите все проверки и перебалансируйте портфель на следующий час.
#
# a. Рассчитайте реализованную доходность этой стратегии, предполагая, что вы можете торговать по средним котировкам (теоретический портфель). Каков его коэффициент Шарпа?
#
# b. Рассчитайте реализованную доходность этой стратегии, предполагая, что вы должны покупать по лучшему аску и продавать по лучшему биду (реальный портфель). Каков его коэффициент Шарпа?
#
# c. Попробуйте изучить эту стратегию и улучшить ее коэффициент Шарпа. Попробуйте разные горизонты, выбор акций или любые другие модификации алгоритма, которые, по вашему мнению, могут дать лучшие результаты. Перечислите все стратегии, которые вы пробовали, и объясните свои аргументы.

# %%
# Ваш код здесь
